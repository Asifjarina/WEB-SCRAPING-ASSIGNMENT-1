# %% [markdown]
# # WEB SCRAPING ASSIGNMENT

# %%
# !pip install bs4
# Out:
# Requirement already satisfied: bs4 in d:\data science\lib\site-packages (0.0.1)
# Requirement already satisfied: beautifulsoup4 in d:\data science\lib\site-packages (from bs4) (4.12.2)
# Requirement already satisfied: soupsieve>1.2 in d:\data science\lib\site-packages (from beautifulsoup4->bs4) (2.4)

# %%
# !pip install requests
# Out:
# Requirement already satisfied: requests in d:\data science\lib\site-packages (2.31.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in d:\data science\lib\site-packages (from requests) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in d:\data science\lib\site-packages (from requests) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in d:\data science\lib\site-packages (from requests) (1.26.16)
# Requirement already satisfied: certifi>=2017.4.17 in d:\data science\lib\site-packages (from requests) (2023.7.22)

# %% [markdown]
# # 1.Questions

# %%
from urllib.request import urlopen
from bs4 import BeautifulSoup
import pandas as pd

url = "https://en.wikipedia.org/wiki/Main_Page"
html = urlopen(url)
soup = BeautifulSoup(html, "html.parser")
header_tags = soup.find_all(["h1", "h2", "h3", "h4", "h5", "h6"])
header_text = [tag.text for tag in header_tags]
df = pd.DataFrame(header_text, columns=["Header Tags"])

print(df)
# Out:
#                       Header Tags
# 0                       Main Page
# 1            Welcome to Wikipedia
# 2   From today's featured article
# 3                Did you know ...
# 4                     In the news
# 5                     On this day
# 6      From today's featured list
# 7        Today's featured picture
# 8        Other areas of Wikipedia
# 9     Wikipedia's sister projects
# 10            Wikipedia languages

# %%
pip install parser
# Out:
# Note: you may need to restart the kernel to use updated packages.
# ERROR: Could not find a version that satisfies the requirement parser (from versions: none)
# ERROR: No matching distribution found for parser

# %% [markdown]
# # 2.Questions

# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd

# Send a GET request to the website
url = "https://presidentofindia.nic.in/former-presidents.htm"
response = requests.get(url)

# Create a BeautifulSoup object to parse the HTML content
soup = BeautifulSoup(response.content, "html.parser")

# Find the table containing the data
table = soup.find("table")

# Check if the table was found
if table is None:
    print("Table not found on website")
else:
    # Create empty lists to store the data
    names = []
    terms = []

    # Iterate over each row in the table
    for row in table.find_all("tr")[1:]:
        # Extract the name and term of office from the columns
        columns = row.find_all("td")
        name = columns[0].text.strip()
        term = columns[1].text.strip()

        # Append the data to the respective lists
        names.append(name)
        terms.append(term)

    # Create a data frame using the lists
    data = {"Name": names, "Term of Office": terms}
    df = pd.DataFrame(data)

    # Display the data frame
    print(df)
# Out:
# Table not found on website

# %% [markdown]
# # 3.Questions

# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd

# %%
# Scrape Top 10 ODI teams in men's cricket
url_teams = "https://www.icc-cricket.com/rankings/mens/team-rankings/odi"
response_teams = requests.get(url_teams)
soup_teams = BeautifulSoup(response_teams.content, "html.parser")
teams_data = []
table_teams = soup_teams.find("table", class_="table")
rows_teams = table_teams.find_all("tr")
for row in rows_teams[1:11]:
    team_name = row.find("span", class_="u-hide-phablet").text.strip()
    matches = row.find_all("td")[2].text.strip()
    points = row.find_all("td")[3].text.strip()
    rating = row.find_all("td")[4].text.strip()
    teams_data.append([team_name, matches, points, rating])

# %%
# Scrape Top 10 ODI batsmen
url_batsmen = "https://www.icc-cricket.com/rankings/mens/player-rankings/odi/batting"
response_batsmen = requests.get(url_batsmen)
soup_batsmen = BeautifulSoup(response_batsmen.content, "html.parser")
batsmen_data = []
table_batsmen = soup_batsmen.find("table", class_="table")
rows_batsmen = table_batsmen.find_all("tr")
if row.find("td", class_="table-body__cell rankings-table__name name") is not None:
    player_name = row.find("td", class_="table-body__cell rankings-table__name name").text.strip()

# %%
# Scrape Top 10 ODI bowlers
url_bowlers = "https://www.icc-cricket.com/rankings/mens/player-rankings/odi/bowling"
response_bowlers = requests.get(url_bowlers)
soup_bowlers = BeautifulSoup(response_bowlers.content, "html.parser")
bowlers_data = []
table_bowlers = soup_bowlers.find("table", class_="table")
rows_bowlers = table_bowlers.find_all("tr")
if row.find("td", class_="table-body__cell rankings-table__name name") is not None:
    player_name = row.find("td", class_="table-body__cell rankings-table__name name").text.strip()

# %%
# Create data frames
df_teams = pd.DataFrame(teams_data, columns=["Team", "Matches", "Points", "Rating"])
df_batsmen = pd.DataFrame(batsmen_data, columns=["Player", "Team", "Rating"])
df_bowlers = pd.DataFrame(bowlers_data, columns=["Player", "Team", "Rating"])

# Print the data frames
print("Top 10 ODI teams in men's cricket:")
print(df_teams)
print("\nTop 10 ODI Batsmen:")
print(df_batsmen)
print("\nTop 10 ODI Bowlers:")
print(df_bowlers)
# Out:
# Top 10 ODI teams in men's cricket:
#            Team Matches Points Rating
# 0         India      55  6,640    121
# 1     Australia      42  4,926    117
# 2  South Africa      34  3,750    110
# 3      Pakistan      36  3,922    109
# 4   New Zealand      43  4,399    102
# 5       England      38  3,777     99
# 6     Sri Lanka      47  4,134     88
# 7    Bangladesh      44  3,836     87
# 8   Afghanistan      30  2,533     84
# 9   West Indies      38  2,582     68
#
# Top 10 ODI Batsmen:
# Empty DataFrame
# Columns: [Player, Team, Rating]
# Index: []
#
# Top 10 ODI Bowlers:
# Empty DataFrame
# Columns: [Player, Team, Rating]
# Index: []

# %% [markdown]
# # 4.Questions

# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd

# Scrape Top 10 ODI teams in women's cricket
url_teams = "https://www.icc-cricket.com/rankings/womens/team-rankings/odi"
response_teams = requests.get(url_teams)
soup_teams = BeautifulSoup(response_teams.content, "html.parser")
teams_data = []
table_teams = soup_teams.find("table", class_="table")
rows_teams = table_teams.find_all("tr")
for row in rows_teams[1:11]:
    team_name = row.find("span", class_="u-hide-phablet").text.strip()
    matches = row.find_all("td")[2].text.strip()
    points = row.find_all("td")[3].text.strip()
    rating = row.find_all("td")[4].text.strip()
    teams_data.append([team_name, matches, points, rating])

# Scrape Top 10 women's ODI Batting players
url_batting = "https://www.icc-cricket.com/rankings/womens/player-rankings/odi/batting"
response_batting = requests.get(url_batting)
soup_batting = BeautifulSoup(response_batting.content, "html.parser")
batting_data = []
table_batting = soup_batting.find("table", class_="table")
rows_batting = table_batting.find_all("tr")
for row in rows_batting[1:11]:
    player_name_element = row.find("td", class_="table-body__cell rankings-table__name name")
    if player_name_element is None:
        continue
    player_name = player_name_element.text.strip()
    team_element = row.find("span", class_="table-body__logo-text")
    if team_element is None:
        continue
    team = team_element.text.strip()
    rating_element = row.find("td", class_="table-body__cell rating")
    if rating_element is None:
        continue
    rating = rating_element.text.strip()
    batting_data.append([player_name, team, rating])

# Scrape Top 10 women's ODI all-rounders
url_allrounders = "https://www.icc-cricket.com/rankings/womens/player-rankings/odi/all-rounder"
response_allrounders = requests.get(url_allrounders)
soup_allrounders = BeautifulSoup(response_allrounders.content, "html.parser")
allrounders_data = []
table_allrounders = soup_allrounders.find("table", class_="table")
rows_allrounders = table_allrounders.find_all("tr")
for row in rows_allrounders[1:11]:
    player_name_element = row.find("td", class_="table-body__cell rankings-table__name name")
    if player_name_element is None:
        continue
    player_name = player_name_element.text.strip()
    team_element = row.find("span", class_="table-body__logo-text")
    if team_element is None:
        continue
    team = team_element.text.strip()
    rating_element = row.find("td", class_="table-body__cell rating")
    if rating_element is None:
        continue
    rating = rating_element.text.strip()
    allrounders_data.append([player_name, team, rating])

# Create data frames
df_teams = pd.DataFrame(teams_data, columns=["Team", "Matches", "Points", "Rating"])
df_batting = pd.DataFrame(batting_data, columns=["Player", "Team", "Rating"])
df_allrounders = pd.DataFrame(allrounders_data, columns=["Player", "Team", "Rating"])

# Print the data frames
print("Top 10 ODI teams in women's cricket:")
print(df_teams)
print("\nTop 10 women's ODI Batting players:")
print(df_batting)
print("\nTop 10 women's ODI all-rounders:")
print(df_allrounders)
# Out:
# Top 10 ODI teams in women's cricket:
#            Team Matches Points Rating
# 0     Australia      21  3,429    163
# 1       England      23  2,991    130
# 2  South Africa      21  2,446    116
# 3         India      18  1,745     97
# 4   New Zealand      21  2,014     96
# 5   West Indies      20  1,768     88
# 6     Sri Lanka       9    714     79
# 7    Bangladesh      14  1,074     77
# 8      Thailand      11    753     68
# 9      Pakistan      24  1,602     67
#
# Top 10 women's ODI Batting players:
#                 Player Team Rating
# 0          Beth Mooney  AUS    750
# 1  Chamari Athapaththu   SL    736
# 2      Laura Wolvaardt   SA    727
# 3      Smriti Mandhana  IND    708
# 4         Alyssa Healy  AUS    698
# 5         Ellyse Perry  AUS    697
# 6     Harmanpreet Kaur  IND    694
# 7          Meg Lanning  AUS    662
# 8       Marizanne Kapp   SA    642
#
# Top 10 women's ODI all-rounders:
#                  Player Team Rating
# 0      Ashleigh Gardner  AUS    377
# 1  Natalie Sciver-Brunt  ENG    360
# 2       Hayley Matthews   WI    358
# 3           Amelia Kerr   NZ    346
# 4         Deepti Sharma  IND    312
# 5          Ellyse Perry  AUS    282
# 6              Nida Dar  PAK    240
# 7         Jess Jonassen  AUS    227
# 8         Sophie Devine   NZ    227

# %% [markdown]
# # 5.Questions

# %%
page = requests.get('https://www.cnbc.com/world/?region=world')
soup = BeautifulSoup(page.content, 'html.parser')

headlines = []
times = []
news_links = []

for article in soup.find_all('div', class_='Card-titleContainer'):
    headlines.append(article.find('a').text.strip())
    if article.find('time') is not None:
        times.append(article.find('time').text.strip())
    else:
        times.append('N/A')
    news_links.append(article.find('a')['href'])

df = pd.DataFrame({'Headline': headlines, 'Time': times, 'News Link': news_links})
df
# Out:
#                                              Headline Time  \
# 0   Dow begins December flat after average ends No...  N/A
# 1   Stocks making the biggest moves premarket: Pfi...  N/A
# 2   UAE seeks to silence critics with $30-billion ...  N/A
# 3   Progress on sustainability in the fashion indu...  N/A
# 4   Bill Gates warns the world is likely to oversh...  N/A
# 5   Estonian PM calls on global powers to emulate ...  N/A
# 6   Bill Gates shares his ‘big hope’ for the COP28...  N/A
# 7   Op-ed: With continued geopolitical conflicts, ...  N/A
# 8   Ukraine war live updates: Zelenskyy calls for ...  N/A
# 9   Multiple civilians injured in strikes on Ukrai...  N/A
# 10  Russia slams Finland's border closure, warns t...  N/A
# 11  Finland to close entire border with Russia; wi...  N/A
# 12               CNBC's Sustainable Future Forum 2023  N/A
# 13  Wind power industry in moment of reckoning as ...  N/A
# 14  CEO on why natural gas infrastructure must be ...  N/A
# 15  Why one Tesla manager thinks used cars are 'ab...  N/A
# 16  Volvo Cars CEO strikes cautious tone on solid-...  N/A
# 17  Southeast Asia is on the cusp of a 'supercharg...  N/A
# 18  Cambodia's deputy prime minister: BRI has help...  N/A
# 19  Southeast Asia's first luxury hotel made from ...  N/A
# 20  Ahead of Indonesia’s elections, critics slam J...  N/A
# 21  Laos is spiraling toward a debt crisis as Chin...  N/A
# 22  Pack your jerseys. The era of 'sports tourism'...  N/A
# 23  See the photos that made National Geographic's...  N/A
# 24  The ultimate work perk? This company provides ...  N/A
# 25  Fear is driving Chinese travelers away from tw...  N/A
# 26  A UNESCO World Heritage site with thousands of...  N/A
# 27  Your network is the key to your career, says t...  N/A
# 28  Parenting tips from a dad who’s fostered 36 ki...  N/A
# 29  6 tips to really disconnect from work for the ...  N/A
# 30  Study: Anxious dads raise smarter, more well-b...  N/A
# 31  On ChatGPT's one-year anniversary, it has more...  N/A
#
#                                             News Link
# 0   https://www.cnbc.com/2023/11/30/stock-market-t...
# 1   https://www.cnbc.com/2023/12/01/stocks-making-...
# 2   https://www.cnbc.com/2023/12/01/uae-commits-30...
# 3   https://www.cnbc.com/video/2023/12/01/sustaina...
# 4   https://www.cnbc.com/2023/12/01/bill-gates-war...
# 5   https://www.cnbc.com/video/2023/12/01/estonian...
# 6   https://www.cnbc.com/2023/12/01/bill-gates-sha...
# 7   https://www.cnbc.com/2023/12/01/op-ed-war-is-a...
# 8   https://www.cnbc.com/2023/12/01/russia-ukraine...
# 9   https://www.cnbc.com/2023/11/30/ukraine-war-li...
# 10  https://www.cnbc.com/2023/11/29/ukraine-war-li...
# 11  https://www.cnbc.com/2023/11/28/ukraine-war-li...
# 12  https://www.cnbc.com/2023/11/29/cnbcs-sustaina...
# 13  https://www.cnbc.com/2023/11/13/wind-power-ind...
# 14  https://www.cnbc.com/2023/11/09/ceo-on-why-nat...
# 15  https://www.cnbc.com/2023/11/02/one-tesla-mana...
# 16  https://www.cnbc.com/2023/10/27/volvo-cars-ceo...
# 17  https://www.cnbc.com/2023/11/29/southeast-asia...
# 18  https://www.cnbc.com/video/2023/11/27/cambodia...
# 19  https://www.cnbc.com/2023/11/27/a-new-luxury-h...
# 20  https://www.cnbc.com/2023/11/20/indonesia-pres...
# 21  https://www.cnbc.com/2023/11/09/laos-is-spiral...
# 22  https://www.cnbc.com/2023/11/27/pack-your-jers...
# 23  https://www.cnbc.com/2023/11/23/best-photograp...
# 24  https://www.cnbc.com/2023/11/23/remote-company...
# 25  https://www.cnbc.com/2023/11/20/fear-driving-c...
# 26  https://www.cnbc.com/2023/11/12/a-unesco-world...
# 27  https://www.cnbc.com/video/2023/12/01/your-net...
# 28  https://www.cnbc.com/2023/12/01/parenting-tips...
# 29  https://www.cnbc.com/2023/11/30/6-tips-to-real...
# 30  https://www.cnbc.com/2023/11/30/study-anxious-...
# 31  https://www.cnbc.com/2023/11/30/chatgpts-one-y...

# %% [markdown]
# # 6.Questions

# %%
page = requests.get('https://www.journals.elsevier.com/artificial-intelligence/most-downloaded-articles')
Books = BeautifulSoup(page.content)

Title = []
for i in Books.find_all('h2'):
    Title.append(i.text)

Author = []
for i in Books.find_all('span', class_='sc-1w3fpd7-0 pgLAT'):
    Author.append(i.text)

Date = []
for i in Books.find_all('span', class_='sc-1thf9ly-2 bKddwo'):
    Date.append(i.text)

if len(Title) == len(Author) == len(Date):
    df = pd.DataFrame({'Paper Title': Title, 'Authors': Author, 'Published Date': Date})
else:
    print('Error: Arrays are not of the same length')
# Out:
# Error: Arrays are not of the same length

# %% [markdown]
# # 7.questions

# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd

# Send a GET request to the website
url = "https://www.dineout.co.in"
response = requests.get(url)

# Create a BeautifulSoup object to parse the HTML content
soup = BeautifulSoup(response.content, 'html.parser')

# Find the elements containing the details you want to scrape
restaurant_names = soup.find_all('h2', class_='restnt-name ellipsis')
cuisines = soup.find_all('span', class_='double-line-ellipsis')
locations = soup.find_all('span', class_='double-line-ellipsis')
ratings = soup.find_all('span', class_='rating-value')
image_urls = soup.find_all('img', class_='img-responsive')

# Create empty lists to store the scraped data
restaurant_list = []
cuisine_list = []
location_list = []
rating_list = []
image_url_list = []

# Extract the data from the elements and append them to the respective lists
for name in restaurant_names:
    restaurant_list.append(name.text.strip())

for cuisine in cuisines:
    cuisine_list.append(cuisine.text.strip())

for location in locations:
    location_list.append(location.text.strip())

for rating in ratings:
    rating_list.append(rating.text.strip())

for image in image_urls:
    image_url_list.append(image['src'])

# Create a dictionary from the lists
data = {
    'Restaurant Name': restaurant_list,
    'Cuisine': cuisine_list,
    'Location': location_list,
    'Ratings': rating_list,
    'Image URL': image_url_list
}

# Create a data frame from the dictionary
df = pd.DataFrame(data)

# Print the data frame
print(df)
# Out:
# Empty DataFrame
# Columns: [Restaurant Name, Cuisine, Location, Ratings, Image URL]
# Index: []
